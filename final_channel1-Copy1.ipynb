# %% [markdown]
# # Importing libraries for fault detection

# %%
import pandas as pd
import pandas as pd
import glob
from scipy.io import loadmat
import scipy.io as sio
from matplotlib import cm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
#from sklearn import confusion_matrix
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
import model_evaluation_utils as meu
#from graphviz import Source
#import graphviz
from io import StringIO
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier


from sklearn import metrics
#import pydotplus
from sklearn import tree 
from IPython.display import Image
#from skater.core.explanations import Interpretation
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
#from pyrcn.datasets import load_digits
#from pyrcn.echo_state_network import ESNClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import preprocessing
# %matplotlib inline
# %matplotlib inline
# %matplotlib notebook

# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %% [markdown]
# # Five kinds of faults & four kinds of speed variation

# %%
import pandas as pd
import data
DnI=data.DnI
IS=data.IS
DS=data.DS
IDS=data.IDS
del DS['DS_3']
del DS['DS_4']
del IDS['IDS_3']
del IDS['IDS_4']
del IS['IS_3']
del IS['IS_4']
df=pd.concat([DnI,IS['IS_2'],DS['DS_2'],IDS['IDS_2']],axis=1).sample(frac=0.1)
df.rename(columns={'DnI_3':'Status','DnI_4':'Result'},inplace=True)
df=df[['DnI_2','DS_2','IS_2','IDS_2','Status','Result']]
#outdata=df.to_dict('list')
#sio.savemat('final.mat',outdata)
le = LabelEncoder()
label = le.fit_transform(df['Status'])
df["Category"] = label

# %% [markdown]
# ## Implementating Decision Tree Model for all columns

# %% [markdown]
# ## Decision tree for fault classification

# %% [markdown]
# #### Multi-Class Classification

# %%
 print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
#tree.plot_tree(dt)
del X
del y

#### Binary Classification
# Out:
# Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition
# [2 2 2 ... 5 4 0]
# DecisionTreeClassifier(random_state=42)
# (600000,) (600000,)
# Accuracy: 0.4911
# Precision: 0.4911
# Recall: 0.4911
# F1 Score: 0.491
#               precision    recall  f1-score   support
#
#            1       0.30      0.31      0.31     40032
#            0       0.66      0.66      0.66    119435
#
#    micro avg       0.57      0.57      0.57    159467
#    macro avg       0.48      0.49      0.48    159467
# weighted avg       0.57      0.57      0.57    159467
#
# DecisionTrees's Accuracy:  0.491075
# DecisionTrees's Accuracy:  0.491075
# Train set Accuracy:  0.9781233333333333
# Test set Accuracy:  0.491075
# Score: 0.48821666666666663
# <div id='14d95b73-16b4-46fd-ad2a-a3e5a37fc08a'></div>

# %%
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
X = df[['DnI_2','IS_2','IDS_2','DS_2']]
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y
# Out:
# Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition
# [0 0 0 ... 1 1 1]
# DecisionTreeClassifier(random_state=42)
# (600000,) (600000,)
# Accuracy: 0.804
# Precision: 0.8066
# Recall: 0.804
# F1 Score: 0.8053
#               precision    recall  f1-score   support
#
#            1       0.88      0.87      0.88    479470
#            0       0.51      0.53      0.52    120530
#
#     accuracy                           0.80    600000
#    macro avg       0.70      0.70      0.70    600000
# weighted avg       0.81      0.80      0.81    600000
#
# DecisionTrees's Accuracy:  0.8040316666666667
# DecisionTrees's Accuracy:  0.8040316666666667
# Train set Accuracy:  0.994015
# Test set Accuracy:  0.8040316666666667
# Score: 0.801715
# <div id='c7da1566-9813-4028-8466-5d71ca0cb5b5'></div>

# %% [markdown]
# ## In this Dataset, Decision tree classifier is better for  binary classification but not multiclass classification

# %% [markdown]
# ### Decision Tree Classsifier for individual column

# %% [markdown]
# #### Binary Classification

# %% [markdown]
# #### Increasing Speed

# %%
print('Columns for test data is Increasing Speed ' )
#df=df.sample(frac=0.10)
X = df[['IS_2']].copy()
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y
# Out:
# Columns for test data is Increasing Speed
# [0 0 0 ... 1 1 1]
# DecisionTreeClassifier(random_state=42)
# (600000,) (600000,)
# Accuracy: 0.804
# Precision: 0.8066
# Recall: 0.804
# F1 Score: 0.8053
#               precision    recall  f1-score   support
#
#            1       0.88      0.87      0.88    479470
#            0       0.51      0.53      0.52    120530
#
#     accuracy                           0.80    600000
#    macro avg       0.70      0.70      0.70    600000
# weighted avg       0.81      0.80      0.81    600000
#
# DecisionTrees's Accuracy:  0.8040316666666667
# DecisionTrees's Accuracy:  0.8040316666666667
# Train set Accuracy:  0.994015
# Test set Accuracy:  0.8040316666666667
# Score: 0.801715
# <div id='c3b01fd9-9df9-42f4-8a95-fd15910379a4'></div>

# %% [markdown]
# #### Decreasing Speed

# %%
print('Columns for test data is Decreasing Speed' )
#df=df.sample(frac=0.10)
X = df[['DS_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y
# Out:
# Columns for test data is Decreasing Speed
# [1 1 1 ... 1 1 1]
# DecisionTreeClassifier(random_state=42)
# (600000,) (600000,)
# Accuracy: 0.7976
# Precision: 0.6818
# Recall: 0.7976
# F1 Score: 0.7102
#               precision    recall  f1-score   support
#
#            1       0.80      1.00      0.89    479470
#            0       0.22      0.00      0.01    120530
#
#     accuracy                           0.80    600000
#    macro avg       0.51      0.50      0.45    600000
# weighted avg       0.68      0.80      0.71    600000
#
# DecisionTrees's Accuracy:  0.79761
# DecisionTrees's Accuracy:  0.79761
# Train set Accuracy:  0.7999454166666666
# Test set Accuracy:  0.79761
# Score: 0.7955633333333333
# <div id='e4a2abc5-45c8-4180-8fb3-10e6ef9df831'></div>

# %% [markdown]
# # For Binary Decision Tree Classifier for individual Condition , accurarcy is same for all columns

# %% [markdown]
# ### Multi-Class Individual Classification

# %%
print('Columns for test data is Decreasing and Increasing Speed' )
#df=df.sample(frac=0.10)
X = df[['DnI_2']]
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y
# Out:
# Columns for test data is Decreasing and Increasing Speed
# [4 2 2 ... 4 5 4]
# DecisionTreeClassifier(random_state=42)
# (600000,) (600000,)
# Accuracy: 0.4075
# Precision: 0.3741
# Recall: 0.4075
# F1 Score: 0.3796
#               precision    recall  f1-score   support
#
#            1       0.06      0.00      0.00     40032
#            0       0.46      0.60      0.52    119435
#
#    micro avg       0.46      0.45      0.45    159467
#    macro avg       0.26      0.30      0.26    159467
# weighted avg       0.36      0.45      0.39    159467
#
# DecisionTrees's Accuracy:  0.40746333333333334
# DecisionTrees's Accuracy:  0.40746333333333334
# Train set Accuracy:  0.4164233333333333
# Test set Accuracy:  0.40746333333333334
# Score: 0.40556000000000003
# <div id='9aa75d85-ab6b-4b54-9683-ebdf07be505f'></div>

# %% [markdown]
# ## For multi-class classification using decision tree for individual column is not very good choice

# %% [markdown]
# # Logistic Regression Model for all columns

# %% [markdown]
# ## Multi Class Classification

# %%
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = LogisticRegression()
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Logistic Regression Accuracy ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y
# Out:
# Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition
# [2 2 0 ... 2 0 2]
# LogisticRegression()
# (600000,) (600000,)
# Accuracy: 0.2002
# Precision: 0.1596
# Recall: 0.2002
# F1 Score: 0.1463
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00     40032
#            0       0.20      0.44      0.27    119435
#
#    micro avg       0.20      0.33      0.25    159467
#    macro avg       0.10      0.22      0.14    159467
# weighted avg       0.15      0.33      0.21    159467
#
# Logistic Regression Accuracy  0.20017
# Train set Accuracy:  0.20041083333333334
# Test set Accuracy:  0.20017
# Score: 0.20158166666666663
# <div id='72d21fdb-b115-46cb-b3e8-e0835481c118'></div>

# %% [markdown]
# ## Binary Class Classification

# %%
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
#X = df[['DnI_2','IS_2','IDS_2','DS_2']]
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = LogisticRegression(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("LogisticRegression's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y
# Out:
# Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition
# [1 1 1 ... 1 1 1]
# LogisticRegression(random_state=42)
# (600000,) (600000,)
# Accuracy: 0.7991
# Precision: 0.6386
# Recall: 0.7991
# F1 Score: 0.7099
#               precision    recall  f1-score   support
#
#            1       0.80      1.00      0.89    479470
#            0       0.00      0.00      0.00    120530
#
#     accuracy                           0.80    600000
#    macro avg       0.40      0.50      0.44    600000
# weighted avg       0.64      0.80      0.71    600000
#
# LogisticRegression's Accuracy:  0.7991166666666667
# Train set Accuracy:  0.7995291666666666
# Test set Accuracy:  0.7991166666666667
# Score: 0.7991166666666667
# <div id='ef15b11d-9765-476d-b55d-9f6b740b8a81'></div>

# %% [markdown]
# ## Logistic Regression binary class is better than multi class for all columns

# %% [markdown]
# ### Individual Columns

# %%
print('Columns for test data is Increasing Speed ' )
#df=df.sample(frac=0.10)
X = df[['DnI_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = LogisticRegression(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Logistic Regression's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y
# Out:
# Columns for test data is Increasing Speed
# [1 1 1 ... 1 1 1]
# LogisticRegression(random_state=42)
# (600000,) (600000,)
# Accuracy: 0.7991
# Precision: 0.6386
# Recall: 0.7991
# F1 Score: 0.7099
#               precision    recall  f1-score   support
#
#            1       0.80      1.00      0.89    479470
#            0       0.00      0.00      0.00    120530
#
#     accuracy                           0.80    600000
#    macro avg       0.40      0.50      0.44    600000
# weighted avg       0.64      0.80      0.71    600000
#
# Logistic Regression's Accuracy:  0.7991166666666667
# Train set Accuracy:  0.7995291666666666
# Test set Accuracy:  0.7991166666666667
# Score: 0.7991166666666667
# <div id='604ccdbe-8456-4ca3-8142-f8c770bb9f2c'></div>

# %%
print('Columns for test data is Increasing Speed ,' )
#df=df.sample(frac=0.10)
X = df[['IS_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = LogisticRegression(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Logistic Regression's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y
# Out:
# Columns for test data is Increasing Speed ,
# [1 1 1 ... 1 1 1]
# LogisticRegression(random_state=42)
# (600000,) (600000,)
# Accuracy: 0.7991
# Precision: 0.6386
# Recall: 0.7991
# F1 Score: 0.7099
#               precision    recall  f1-score   support
#
#            1       0.80      1.00      0.89    479470
#            0       0.00      0.00      0.00    120530
#
#     accuracy                           0.80    600000
#    macro avg       0.40      0.50      0.44    600000
# weighted avg       0.64      0.80      0.71    600000
#
# Logistic Regression's Accuracy:  0.7991166666666667
# Train set Accuracy:  0.7995291666666666
# Test set Accuracy:  0.7991166666666667
# Score: 0.7991166666666667
# <div id='1eeb274a-ee9b-4bee-8c14-1538188e13a0'></div>

# %%
print('Columns for test data is Increasing Speed' )
#df=df.sample(frac=0.10)
X = df[['DnI_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = LogisticRegression()
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Logistic Regression's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y
# Out:
# Columns for test data is Increasing Speed
# [2 2 0 ... 2 0 2]
# LogisticRegression()
# (600000,) (600000,)
# Accuracy: 0.2002
# Precision: 0.0801
# Recall: 0.2002
# F1 Score: 0.1144
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00     40032
#            0       0.20      0.50      0.29    119435
#
#    micro avg       0.20      0.37      0.26    159467
#    macro avg       0.10      0.25      0.14    159467
# weighted avg       0.15      0.37      0.21    159467
#
# Logistic Regression's Accuracy:  0.200175
# Train set Accuracy:  0.20030791666666667
# Test set Accuracy:  0.200175
# Score: 0.20018166666666665
# <div id='e162f173-f9ea-45af-ba68-ede582ced822'></div>

# %%
print(' Decreasing Speed,')
#df=df.sample(frac=0.10)
X = df[['DS_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = LogisticRegression(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("logistc regression's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y
# Out:
#  Decreasing Speed,
# [0 5 0 ... 5 5 0]
# LogisticRegression(random_state=42)
# (600000,) (600000,)
# Accuracy: 0.2007
# Precision: 0.124
# Recall: 0.2007
# F1 Score: 0.1204
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00     40032
#            0       0.20      0.50      0.29    119435
#
#    micro avg       0.20      0.37      0.26    159467
#    macro avg       0.10      0.25      0.14    159467
# weighted avg       0.15      0.37      0.21    159467
#
# logistc regression's Accuracy:  0.20071166666666668
# DecisionTrees's Accuracy:  0.20071166666666668
# Train set Accuracy:  0.20019708333333333
# Test set Accuracy:  0.20071166666666668
# Score: 0.20073166666666667
# <div id='d3118d67-f341-4442-9d1c-132c21a67d32'></div>

# %% [markdown]
# ## For individual column also ,logistic regression in binary having better accuarcy than multiclass

# %% [markdown]
# # Random Forest Classifier for all columns

# %% [markdown]
# ## Multi Class

# %%
df1=df.sample(frac=0.1)
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)

X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = RandomForestClassifier()
dt.fit(X_train,y_train)
#df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Random Forest Classifier's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
plt.show()
del X
del y
# Out:
# Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition

# %% [markdown]
# ### Binary Class

# %%
df1=df.sample(frac=0.1)
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)

X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = RandomForestClassifier(random_state=42)
dt.fit(X_train,y_train)
#df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Random Forest Classifier's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
plt.show()
del X
del y
del dt

# %% [markdown]
# ## for Random Forest Classifer , binary class giving more accuracy

# %% [markdown]
# ### Individual Columns

# %% [markdown]
# #### Binary Class

# %%
print('Columns for test data is Increasing Speed ,' )
#df=df.sample(frac=0.10)
X = df[['IS_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = RandomForestClassifier(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Random Forest Classifier's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
plt.show()
del X
del y

# %% [markdown]
# #### Multi -Class Classification

# %%
print('Columns for test data is Increasing Speed ,' )
#df=df.sample(frac=0.10)
X = df[['IS_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = RandomForestClassifier(random_state=42)
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Random Forest Classifier's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
plt.show()
a=[X,y]
del a

# %% [markdown]
# ### Comment for Random Forest Classifer on Individual Column binary & multi here

# %% [markdown]
# # Gaussian Model

# %% [markdown]
# ### Binary Classification

# %%
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = GaussianNB()
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Gaussian NB's accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y

# %% [markdown]
# ### Multi-Class Classification

# %%
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)

X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = GaussianNB()
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Gaussian NB's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y

# %% [markdown]
# # Gaussian NB for all columns binary & multiclass comment

# %% [markdown]
# ## Gaussian NB for individual Columns

# %% [markdown]
# ### Multi-Class Classification

# %%
print('Columns for test data is Increasing Speed ,' )
#df=df.sample(frac=0.10)
X = df[['IS_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = GaussianNB()
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Gaussian NB's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y

# %% [markdown]
# ### Binary

# %%
print('Columns for test data is Increasing Speed ,' )
#df=df.sample(frac=0.10)
X = df[['IS_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
dt = GaussianNB()
dt.fit(X_train,y_train)
df['dni_p']=dt.predict(X)
test_predictions=dt.predict(X_test)
print(test_predictions)
print(dt)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())

print("Gaussian NB's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
#print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, dt.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(dt, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dt,X_test,y_test)
del X
del y

# %% [markdown]
# ## Gaussian NB comment for individual class

# %% [markdown]
# # MLP Classifier for all columns

# %% [markdown]
# ## Multi-Class Classification

# %%
from sklearn.neural_network import MLPClassifier
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
X=np.float64(X)
warnings.filterwarnings('ignore')
y=np.float64(y)
clf = MLPClassifier(random_state=1, max_iter=300).fit(X_train, y_train)
#clf.predict_proba(X_test[:1])

print(clf.predict(X_test))


print(clf.score(X_test, y_test))

metrics.plot_confusion_matrix(clf,X_test,y_test)


test_predictions=clf.predict(X_test)
print(test_predictions)
print(clf)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Category.unique())
#print(y_test)

del X
del y

# %%
from sklearn.neural_network import MLPClassifier
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
X=np.float64(X)
warnings.filterwarnings('ignore')
y=np.float64(y)
clf = MLPClassifier(random_state=1, max_iter=600).fit(X_train, y_train)
#clf.predict_proba(X_test[:1])

print(clf.predict(X_test))


print(clf.score(X_test, y_test))
metrics.plot_confusion_matrix(clf,X_test,y_test)


test_predictions=clf.predict(X_test)
print(test_predictions)
print(clf)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Category.unique())

#print(y_test)

del X
del y

# %% [markdown]
# ## Binary Classification

# %%
from sklearn.neural_network import MLPClassifier
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
warnings.filterwarnings('ignore')
X=np.float64(X)
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
y=np.float64(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
X=np.float64(X)
warnings.filterwarnings('ignore')
y=np.float64(y)
clf = MLPClassifier(random_state=1, max_iter=600).fit(X_train, y_train)
#clf.predict_proba(X_test[:1])
print('hello')
print(clf.predict(X_test))


z=clf.score(X_test, y_test)
print(z)
metrics.plot_confusion_matrix(clf,X_test,y_test)






test_predictions=clf.predict(X_test)
print(test_predictions)
print(clf)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())















#print(y_test)

del X
del y

# %% [markdown]
# ## Comparison of accuracy for multi-class and binary class for MLP classifer

# %% [markdown]
# ### Indiviual column and binary classification

# %%
from sklearn.neural_network import MLPClassifier
print('Columns for test data is Increasing Speed , ' )
#df=df.sample(frac=0.10)
X = df[['IS_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
X=np.float64(X)
warnings.filterwarnings('ignore')
y=np.float64(y)
clf = MLPClassifier(random_state=1, max_iter=600).fit(X_train, y_train)
#clf.predict_proba(X_test[:1])

print(clf.predict(X_test))


print(clf.score(X_test, y_test))

metrics.plot_confusion_matrix(clf,X_test,y_test)


#print(y_test)
test_predictions=clf.predict(X_test)
print(test_predictions)
print(clf)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())
del X
del y

# %% [markdown]
# ### Multi-Class Classification

# %%
from sklearn.neural_network import MLPClassifier
print('Columns for test data is Increasing Speed , ' )
#df=df.sample(frac=0.10)
X = df[['IS_2']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
X=np.float64(X)
warnings.filterwarnings('ignore')
y=np.float64(y)
clf = MLPClassifier(random_state=1, max_iter=600).fit(X_train, y_train)
clf.predict_proba(X_test[:1])

print(clf.predict(X_test))


print(clf.score(X_test, y_test))
metrics.plot_confusion_matrix(clf,X_test,y_test)



test_predictions=clf.predict(X_test)
print(test_predictions)
print(clf)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Category.unique())
#print(y_test)

del X
del y

# %% [markdown]
# ## Comparison for individual column with binary and multi-class classification

# %% [markdown]
# # KNeighbourClassifier with different neighbors(k)

# %% [markdown]
# ## Modelling for all columns and binary classification

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
st_x= StandardScaler()    
x_train= st_x.fit_transform(X_train)    
x_test= st_x.transform(X_test)
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(x_train,y_train)
 pred_i = knn.predict(x_test)
 error_rate.append(np.mean(pred_i != y_test))
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed',marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
req_k_value = error_rate.index(min(error_rate))+1
print("Minimum error:-",min(error_rate),"at K =",req_k_value)
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors=req_k_value, metric='minkowski', p=2 )  
classifier.fit(x_train, y_train) 
y_pred= classifier.predict(x_test)
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
print("KNN - 10 neighbors Accuracy score and Confusion matrix")
print(accuracy_score(y_pred,y_test))
#print(confusion_matrix(y_test, y_pred))
print("-------------------------")
metrics.plot_confusion_matrix(classifier, x_test, y_test)
plt.show()

# %%
print('k=2')
from sklearn.neighbors import KNeighborsClassifier
X = df[['DnI_2','IDS_2','DS_2','IS_2']].copy()
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

k = 25
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
print(neigh)
test_predictions=neigh.predict(X_test)
meu.get_metrics(true_labels=y_test, predicted_labels=test_predictions)
print("KNeighboursClassifier's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores = cross_val_score(neigh, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(neigh,X_test,y_test)
plt.show()
del X
del y

# %%
#X = df[['DnI_2','IS_2','IDS_2','DS_2']]
y = df['Result']
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

model = KNeighborsClassifier(n_neighbors=20)
model.fit(X_train,y_train)
test_predictions=model.predict(X_test)
meu.get_metrics(true_labels=y_test, predicted_labels=test_predictions)
print("KNeighborsClassifier's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, model.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores = cross_val_score(model, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(model,X_test,y_test)
plt.show()
print(model)
del X
del y

# %% [markdown]
# ## Accuracy comparison for different k and classes

# %% [markdown]
# # KNeighbour Classifier for multi-class for all columns

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
st_x= StandardScaler()    
x_train= st_x.fit_transform(X_train)    
x_test= st_x.transform(X_test)
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(x_train,y_train)
 pred_i = knn.predict(x_test)
 error_rate.append(np.mean(pred_i != y_test))
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed',marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
req_k_value = error_rate.index(min(error_rate))+1
print("Minimum error:-",min(error_rate),"at K =",req_k_value)
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors=req_k_value, metric='minkowski', p=2 )  
classifier.fit(x_train, y_train) 
y_pred= classifier.predict(x_test)
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
print("KNN - 10 neighbors Accuracy score and Confusion matrix")
print(accuracy_score(y_pred,y_test))
#print(confusion_matrix(y_test, y_pred))
print("-------------------------")
metrics.plot_confusion_matrix(classifier, x_test, y_test)
plt.show()

# %%
print('k=2')
from sklearn.neighbors import KNeighborsClassifier
X = df[['DnI_2','IDS_2','DS_2','IS_2']].copy()
y = df['Category'].copy()
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

k = 17
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
print(neigh)
test_predictions=neigh.predict(X_test)
meu.get_metrics(true_labels=y_test, predicted_labels=test_predictions)
print("KNeighboursClassifier's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores = cross_val_score(neigh, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(neigh,X_test,y_test)
plt.show()
del X
del y

# %%
X = df[['DnI_2','IS_2','IDS_2','DS_2']]
y = df['Category']
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

model = KNeighborsClassifier(n_neighbors=20)
model.fit(X_train,y_train)
test_predictions=model.predict(X_test)
meu.get_metrics(true_labels=y_test, predicted_labels=test_predictions)
print("KNeighborsClassifier's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, model.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(model, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(model,X_test,y_test)
print(model)
del X
del y

# %% [markdown]
# ## Accuracy Comparison for different values of k for multi-class classification

# %% [markdown]
# # KNeighbour Classifier for individual columns

# %% [markdown]
# ### Binary Class

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
X = df[['DnI_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
st_x= StandardScaler()    
x_train= st_x.fit_transform(X_train)    
x_test= st_x.transform(X_test)
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(x_train,y_train)
 pred_i = knn.predict(x_test)
 error_rate.append(np.mean(pred_i != y_test))
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed',marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
req_k_value = error_rate.index(min(error_rate))+1
print("Minimum error:-",min(error_rate),"at K =",req_k_value)
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors=req_k_value, metric='minkowski', p=2 )  
classifier.fit(x_train, y_train) 
y_pred= classifier.predict(x_test)
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
print("KNN - 10 neighbors Accuracy score and Confusion matrix")
print(accuracy_score(y_pred,y_test))
#print(confusion_matrix(y_test, y_pred))
print("-------------------------")
metrics.plot_confusion_matrix(classifier, x_test, y_test)
plt.show()

# %%
X = df[['DnI_2','IS_2','IDS_2','DS_2']]
y = df['Result']
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

model = KNeighborsClassifier(n_neighbors=29)
model.fit(X_train,y_train)
test_predictions=model.predict(X_test)
meu.get_metrics(true_labels=y_test, predicted_labels=test_predictions)
print("KNeighborsClassifier's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, model.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(model, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(model,X_test,y_test)
print(model)
del X
del y

# %% [markdown]
# #### Multi-Class

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
X = df[['DnI_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
st_x= StandardScaler()    
x_train= st_x.fit_transform(X_train)    
x_test= st_x.transform(X_test)
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(x_train,y_train)
 pred_i = knn.predict(x_test)
 error_rate.append(np.mean(pred_i != y_test))
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed',marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
req_k_value = error_rate.index(min(error_rate))+1
print("Minimum error:-",min(error_rate),"at K =",req_k_value)
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors=req_k_value, metric='minkowski', p=2 )  
classifier.fit(x_train, y_train) 
y_pred= classifier.predict(x_test)
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
print("KNN - 10 neighbors Accuracy score and Confusion matrix")
print(accuracy_score(y_pred,y_test))
#print(confusion_matrix(y_test, y_pred))
print("-------------------------")
metrics.plot_confusion_matrix(classifier, x_test, y_test)
plt.show()

# %%
X = df[['IDS_2']]
y = df['Category']
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

model = KNeighborsClassifier(n_neighbors=36)
model.fit(X_train,y_train)
test_predictions=model.predict(X_test)
meu.get_metrics(true_labels=y_test, predicted_labels=test_predictions)
print("KNeighborsClassifier's Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
print("Train set Accuracy: ", metrics.accuracy_score(y_train, model.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, test_predictions))
scores=cross_val_score(model, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(model,X_test,y_test)
print(model)
del X
del y

# %% [markdown]
# ## Comparison for individual columns for binary and multi-class classification

# %% [markdown]
# # Accuarcy Comparison for all models of KNeighbour Classifier

# %% [markdown]
# # KNeighbour Regressor Model

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
X = df[['DnI_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
st_x= StandardScaler()    
x_train= st_x.fit_transform(X_train)    
x_test= st_x.transform(X_test)
error_rate = []
for i in range(1,40):
 knn = KNeighborsRegressor(n_neighbors=i)
 knn.fit(x_train,y_train)
 pred_i = knn.predict(x_test)
 error_rate.append(np.mean(pred_i != y_test))
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed',marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
req_k_value = error_rate.index(min(error_rate))+1
print("Minimum error:-",min(error_rate),"at K =",req_k_value)
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors=req_k_value, metric='minkowski', p=2 )  
classifier.fit(x_train, y_train) 
y_pred= classifier.predict(x_test)
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
print("KNN - 10 neighbors Accuracy score and Confusion matrix")
print(accuracy_score(y_pred,y_test))
#print(confusion_matrix(y_test, y_pred))
print("-------------------------")
metrics.plot_confusion_matrix(classifier, x_test, y_test)
plt.show()

# %%
#KNeighbour Regressor for all columns
X = df[['DnI_2','IDS_2','DS_2','IS_2']]
y = df['Result']
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
model = KNeighborsRegressor(n_neighbors=2)
model.fit(X_train,y_train)
test_predictions=model.predict(X_test)
#meu.get_metrics(true_labels=y_test, predicted_labels=test_predictions)

print(model)
scores=cross_val_score(model, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
#metrics.plot_confusion_matrix(model,X_test,y_test)


knnreg = KNeighborsRegressor(n_neighbors = 2).fit(X_train, y_train)

print(knnreg.predict(X_test))
print('R-squared test score: {:.3f}'
     .format(knnreg.score(X_test, y_test)))

# %%
#KNeighbour Regressor for all columns
X = df[['DnI_2','IDS_2','DS_2','IS_2']]
y = df['Result']
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
model = KNeighborsRegressor(n_neighbors=2)
model.fit(X_train,y_train)
test_predictions=model.predict(X_test)
#meu.get_metrics(true_labels=y_test, predicted_labels=test_predictions)

print(model)
scores=cross_val_score(model, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
#metrics.plot_confusion_matrix(model,X_test,y_test)


knnreg = KNeighborsRegressor(n_neighbors = 2).fit(X_train, y_train)

print(knnreg.predict(X_test))
print('R-squared test score: {:.3f}'
     .format(knnreg.score(X_test, y_test)))

# %%
from sklearn.model_selection import GridSearchCV 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
lm_cv= LinearRegression()
X = df[['DnI_2','IDS_2','DS_2','IS_2']]
y = df['Result']
X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
#model = KNeighborsRegressor(n_neighbors=2)
lm_cv.fit(X_train,y_train)
print (cross_val_score(lm_cv, X_train, y_train, cv=10))
print(cross_val_score(lm_cv, X_train, y_train, cv=10).mean())


# Compute RMSE for test data
from sklearn.metrics import mean_squared_error
import math
Predicted_train_cv = lm_cv.fit(X_train, y_train).predict(X_train)
Predicted_cv = lm_cv.fit(X_train, y_train).predict(X_test)
scores=cross_val_score(lm_cv, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
#metrics.plot_confusion_matrix(lm_cv,X_test,y_test)
trainmeanSquaredError=mean_squared_error(y_train, Predicted_train_cv)
print("Train MSE:", trainmeanSquaredError)
trainrootMeanSquaredError = math.sqrt(trainmeanSquaredError)
print("Train RMSE:", trainrootMeanSquaredError)

meanSquaredError=mean_squared_error(y_test, Predicted_cv)
print("Test MSE:", meanSquaredError)
rootMeanSquaredError = math.sqrt(meanSquaredError)
print("Test RMSE:", rootMeanSquaredError)

# %%
sns.displot(df['DnI_2'])

# %%
print(df.corr())
print(df.cov())

# %%
sns.heatmap(df[['DnI_2','IS_2','Category','Result','DS_2']],square=True)
plt.show()

# %%
plt.scatter(df['DnI_2'],df['Category'])
plt.show()
plt.plot()

# %%
sns.violinplot(x ='IS_2', y ='Category', data = df, split = True)
plt.show()

# %%
sns.swarmplot(x ='IDS_2', y ='Category', data = df)
plt.show()

# %%
sns.violinplot(x ='DS_2', y ='Category', data = df)
sns.swarmplot(x ='DS_2', y ='Category', data = df, color ='black')
plt.show()

# %%
sns.boxplot(df['DnI_2'].values,df['Category'].values)
plt.show()

# %%
sns.regplot(x = "IS_2",
            y = "Category", 
            data = df)
  
# show the plot
plt.show()

# %%
from sklearn.cluster import KMeans
X = df[['DnI_2','IDS_2','DS_2','IS_2']]
y = df['Result']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
km = KMeans(n_clusters=2, random_state=92)
km.fit(X)
labels = km.labels_
labels[:10]
km.cluster_centers_

# %%
km3 = KMeans(n_clusters=3, random_state=92)
km3.fit(X)

labels3 = km3.labels_
km3.cluster_centers_
km3.predict(X)

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Generating the sample data from make_blobs
# This particular setting has one distinct cluster and 3 clusters placed close
# together.

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(XS[:, 0], XS[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()

# %%
from sklearn.preprocessing import StandardScaler
  
scalar = StandardScaler()
  
# fitting
scalar.fit(X)
scaled_data = scalar.transform(X)
  
# Importing PCA
from sklearn.decomposition import PCA
  
# Let's say, components = 2
pca = PCA(n_components = 2)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)
  
#x_pca.shape()
plt.figure(figsize =(8, 6))
  
plt.scatter(x_pca[:, 0], x_pca[:, 1], cmap ='DnI_2')
  
# labeling x and y axes
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
df_comp = pd.DataFrame(pca.components_)
  
plt.figure(figsize =(14, 6))
  
# plotting heatmap
sns.heatmap(df_comp)
print('*************** PCA Summary ***************')
print('No. of features: ', pca.n_features_)
print('No. of samples: ', pca.n_samples_)
print('No. of components: ', pca.n_components_)
print('Explained variance ratio: ', pca.explained_variance_ratio_)

# %%
#tree.plot_tree(drugTree)
#plt.show()
#drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
#LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
#predict_proba returns estimates for all classes, ordered by the label of classes. So, the first column is the probability of class 0, P(Y=0|X), 
#and second column is probability of class 1, P(Y=1|X):
#yhat_prob = LR.predict_proba(X_test)
#yhat_prob
from sklearn.metrics import jaccard_score
jaccard_score(y_test, yhat,pos_label=0)
from sklearn.metrics import log_loss
log_loss(y_test, yhat_prob)

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import KMeans
#x = iris_x_df.iloc[:, :].values
wcs = []  #wcss stands for 'within cluster sum of squares'

for i in range(1, 21):
    model = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 250, n_init = 15, random_state = 0)
    model.fit(X)
    wcs.append(model.inertia_)

print(wcs)
plt.plot(range(1, 21), wcs, color = 'r')
plt.title('Number of Clusters Vs WCS')
plt.xlabel('Number of Clusters')
plt.ylabel('Within Clusters Sum of Squares(wcs)')
plt.annotate('Elbow', xytext=(6,200), xy=(3,79), arrowprops={'facecolor':'green'})
plt.grid() 
plt.show()
model = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 250, n_init = 15, random_state = 0)
y = model.fit_predict(x)
plt.scatter(x[y == 0, 0], x[y == 0, 1], 
            s = 50, c = 'cyan', label = 'Iris-setosa')
plt.scatter(x[y == 1, 0], x[y == 1, 1], 
            s = 50, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y == 2, 0], x[y == 2, 1],
            s = 50, c = 'green', label = 'Iris-virginica')

# Plotting the centroids of each clusters
plt.scatter(model.cluster_centers_[:, 0], model.cluster_centers_[:,1], 
            s = 75, c = 'red', label = 'Centroids')

plt.legend(loc=1, bbox_to_anchor= (1.4, 1))
plt.grid()
plt.scatter(x[y == 0, 2], x[y == 0, 3], 
            s = 50, c = 'cyan', label = 'Iris-setosa')
plt.scatter(x[y == 1, 2], x[y == 1, 3], 
            s = 50, c = 'yellow', label = 'Iris-versicolour')
plt.scatter(x[y == 2, 2], x[y == 2, 3],
            s = 50, c = 'm', label = 'Iris-virginica')

# Plotting the centroids of each clusters
plt.scatter(model.cluster_centers_[:, 2], model.cluster_centers_[:,3], 
            s = 75, c = 'red', label = 'Centroids')

plt.legend(loc=1, bbox_to_anchor= (1.4, 1))
plt.grid()

# %%
from __future__ import print_function

import keras
from sklearn.decomposition import PCA
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, Adam, Nadam
batch_size = 128
num_classes = 10
epochs = 10
# PREPROCESSING DATA
X = df[['DnI_2','IDS_2','DS_2','IS_2']]
y = df['Result']
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
# Change from matrix to array --> dimension 28x28 to array of dimension 784
#x_train = x_train.reshape(60000, 784)
#x_test = x_test.reshape(10000, 784)

# Change to float datatype
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# Scale the data to lie between 0 to 1
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices (one hot encoding)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
print('Before PCA: ', x_train.shape, 'train samples')
print('Before PCA: ', x_test.shape, 'test samples')

# PCA
pca = PCA(n_components=100)

x_train=pca.fit_transform(x_train)
x_test= pca.transform(x_test)

print('After PCA : ', x_train.shape, 'train samples')
print('After PCA : ', x_test.shape, 'test samples')
# BUILDING THE MODEL
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(100,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
nadam=keras.optimizers.Adam(lr=0.0005)
model.compile(loss='categorical_crossentropy',
              optimizer=nadam,
              metrics=['accuracy'])
# TRAINING THE MODEL
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# EVALUATE TRAINED MODEL
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Scaling the data to normalize
model = KMeans(n_clusters=5).fit(X)

# Visualize it:
plt.figure(figsize=(8, 6))
plt.scatter(df['DnI_2'], d['Result'], c=model.labels_.astype(float))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# %matplotlib inline
#sns.scatterplot(X)
KMean= KMeans(n_clusters=2)
KMean.fit(Z)
label=KMean.predict(Z)
print('f"Silhouette Score(n=2):', {silhouette_score(Z, label)})
KMean= KMeans(n_clusters=3)
KMean.fit(X)
label=KMean.predict(X)
print('fSilhouette Score(n=3):', {silhouette_score(Z, label)})
#sns.scatterplot(Z[0],Z[1],hue=label,palette=’inferno_r’)

# %%
from scipy.stats import norm
from scipy import stats
import seaborn as sns
#import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly as pt
import statistics
import plotly.express as px
from matplotlib.figure import Figure
import plotly.graph_objects as go
fig=go.Figure()
fig=px.scatter_matrix(df)
#pt.plot(fig)
fig.show()
plt.plot(fig)

# %%
print(df)

# %%
print(df.describe())

# %%
from sklearn import svm
clf = svm.SVC(kernel='rbf')
X = df[['DnI_2','IDS_2','DS_2','IS_2']]
y = df['Result']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
clf.fit(X_train,y_train)
yhat = clf.predict(X_test)
yhat[0:5]
from sklearn.metrics import classification_report, confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
X = df[['DnI_2','IDS_2','DS_2','IS_2']]
y = df['Result']
sv = SVC(C=1000)
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
sv.fit(X_train,y_train)
sq=sv.score()
scores = cross_val_score(sv, X_test, y_test, cv=1)
print("Score:", np.mean(scores))
metrics.plot_confusion_matrix(sv,X_test,y_test)
plt.show()
del X
del y

# %%
from sklearn.svm import SVC
X = df[['DnI_2','IDS_2','DS_2','IS_2']]
y = df['Result']

x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)
model = SVC(kernel='rbf', C=1, gamma=0.001, random_state=1)
model.fit(X_train, y_train)
from sklearn.metrics import accuracy_score

y_predict = model.predict(X_test)
score = accuracy_score(y_test, y_predict)
print(score)

# %%
X = df[['DnI_2','IDS_2','DS_2','IS_2']]
y = df['Result']
dtc = DecisionTreeClassifier(criterion='gini',ccp_alpha=0.0012)

dtc.fit(X_train,y_train)
scores = cross_val_score(dtc, X_test, y_test, cv=10)
print("Score:", np.mean(scores),"\n")
metrics.plot_confusion_matrix(dtc,X_test,y_test)
plt.show()
del X
del y

# %%
X = df[['DnI_2','IDS_2','DS_2','IS_2']]
y = df['Result']
from sklearn.tree import plot_tree
plt.figure(figsize=(15,7))
plot_tree(dtc)
plt.show()
