# %%
import pandas as pd
import pandas as pd
import glob
from scipy.io import loadmat
import scipy.io as sio
from matplotlib import cm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
#from sklearn import confusion_matrix
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
import model_evaluation_utils as meu
#from graphviz import Source
#import graphviz
from io import StringIO
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier


from sklearn import metrics
#import pydotplus
from sklearn import tree 
from IPython.display import Image
#from skater.core.explanations import Interpretation
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
#from pyrcn.datasets import load_digits
#from pyrcn.echo_state_network import ESNClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import preprocessing
# %matplotlib inline
# %matplotlib inline
# %matplotlib notebook

# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import pandas as pd
import data
DnI=data.DnI
IS=data.IS
DS=data.DS
IDS=data.IDS
del DS['DS_3']
del DS['DS_4']
del IDS['IDS_3']
del IDS['IDS_4']
del IS['IS_3']
del IS['IS_4']
df=pd.concat([DnI,IS['IS_2'],DS['DS_2'],IDS['IDS_2']],axis=1).sample(frac=0.1)
df.rename(columns={'DnI_3':'Status','DnI_4':'Result'},inplace=True)
df=df[['DnI_2','DS_2','IS_2','IDS_2','Status','Result']]
#outdata=df.to_dict('list')
#sio.savemat('final.mat',outdata)
le = LabelEncoder()
label = le.fit_transform(df['Status'])
df["Category"] = label
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 import data
#       3 DnI=data.DnI
#       4 IS=data.IS
#
# File ~\Downloads\v43hmbwxpm-2-20221124T024842Z-001\v43hmbwxpm-2\output\data.py:52, in <module>
#      50 k=file
#      51 df1=pd.DataFrame()
# ---> 52 newdata=list(zip(newdata[0],newdata[1]))
#      53 df1= pd.DataFrame(newdata,columns=cols)
#      54 df1=df1.astype(float)
#
# MemoryError:

# %%
from sklearn.neural_network import MLPClassifier
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = df[['DnI_1','IS_1','IDS_1','DS_1']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

clf = MLPClassifier(random_state=1, max_iter=300).fit(X_train, y_train)
clf.predict_proba(X_test[:1])

clf.predict(X_test)


print(clf.score(X_test, y_test))


metrics.plot_confusion_matrix(clf,X_test,y_test)
test_predictions=clf.predict(X_test)
print(test_predictions)
print(clf)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Category.unique())
#print(y_test)

del X
del y
# Out:
# Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition
# 0.4563066666666667
# <img src="data:image/png;base64,..." width="432">
# [0 3 2 ... 4 0 5]
# MLPClassifier(max_iter=300, random_state=1)
# (600000,) (600000,)
# Accuracy: 0.4563
# Precision: 0.4215
# Recall: 0.4563
# F1 Score: 0.4353
#               precision    recall  f1-score   support
#
#            4       0.72      0.80      0.76    120490
#            3       0.35      0.22      0.27     80503
#            0       0.35      0.41      0.38    119474
#            2       0.42      0.48      0.45    119775
#            1       0.00      0.00      0.00     39861
#            5       0.38      0.44      0.41    119897
#
#     accuracy                           0.46    600000
#    macro avg       0.37      0.39      0.38    600000
# weighted avg       0.42      0.46      0.44    600000

# %%
from sklearn.neural_network import MLPClassifier
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = df[['DnI_1','IS_1','IDS_1','DS_1']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

clf = MLPClassifier(random_state=1, max_iter=600).fit(X_train, y_train)
clf.predict_proba(X_test[:1])

clf.predict(X_test)


clf.score(X_test, y_test)

print(clf.score(X_test,y_test))
metrics.plot_confusion_matrix(clf,X_test,y_test)

#print(y_test)
test_predictions=clf.predict(X_test)
print(test_predictions)
print(clf)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Category.unique())
del X
del y
# Out:
# Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition
# 0.4563066666666667
# <img src="data:image/png;base64,..." width="432">
# [0 3 2 ... 4 0 5]
# MLPClassifier(max_iter=600, random_state=1)
# (600000,) (600000,)
# Accuracy: 0.4563
# Precision: 0.4215
# Recall: 0.4563
# F1 Score: 0.4353
#               precision    recall  f1-score   support
#
#            4       0.72      0.80      0.76    120490
#            3       0.35      0.22      0.27     80503
#            0       0.35      0.41      0.38    119474
#            2       0.42      0.48      0.45    119775
#            1       0.00      0.00      0.00     39861
#            5       0.38      0.44      0.41    119897
#
#     accuracy                           0.46    600000
#    macro avg       0.37      0.39      0.38    600000
# weighted avg       0.42      0.46      0.44    600000

# %%
from sklearn.neural_network import MLPClassifier
print('Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition' )
#df=df.sample(frac=0.10)
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = df[['DnI_1','IS_1','IDS_1','DS_1']].copy()
X=np.float64(X)
print('hi')
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
y=np.float64(y)
print('z')
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

clf = MLPClassifier(random_state=1, max_iter=600).fit(X_train, y_train)
clf.predict_proba(X_test[:1])

clf.predict(X_test)


l=clf.score(X_test, y_test)
print(l)

metrics.plot_confusion_matrix(clf,X_test,y_test)
test_predictions=clf.predict(X_test)
print(test_predictions)
print(clf)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())
#print(y_test)

del X
del y
# Out:
# Columns for test data is Increasing Speed , Decreasing Speed,Decreasing then Increasing & increasing then decreasing condition
# hi
# z
# 0.8005133333333333
# <img src="data:image/png;base64,..." width="432">
# [1. 1. 0. ... 1. 1. 1.]
# MLPClassifier(max_iter=600, random_state=1)
# (600000,) (600000,)
# Accuracy: 0.8005
# Precision: 0.7473
# Recall: 0.8005
# F1 Score: 0.733
#               precision    recall  f1-score   support
#
#            1       0.81      0.98      0.89    480225
#            0       0.50      0.06      0.11    119775
#
#     accuracy                           0.80    600000
#    macro avg       0.66      0.52      0.50    600000
# weighted avg       0.75      0.80      0.73    600000

# %%
from sklearn.neural_network import MLPClassifier
print('Columns for test data is Increasing Speed , ' )
#df=df.sample(frac=0.10)
X = df[['IS_1']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Result'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

clf = MLPClassifier(random_state=1, max_iter=600).fit(X_train, y_train)
clf.predict_proba(X_test[:1])

clf.predict(X_test)


clf.score(X_test, y_test)
print(clf.score(X_test,y_test))
metrics.plot_confusion_matrix(clf,X_test,y_test)


#print(y_test)
test_predictions=clf.predict(X_test)
print(test_predictions)
print(clf)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Result.unique())
del X
del y
# Out:
# Columns for test data is Increasing Speed ,
# 0.800375
# <img src="data:image/png;base64,..." width="432">
# [1 1 1 ... 1 1 1]
# MLPClassifier(max_iter=600, random_state=1)
# (600000,) (600000,)
# Accuracy: 0.8004
# Precision: 0.6406
# Recall: 0.8004
# F1 Score: 0.7116
#               precision    recall  f1-score   support
#
#            1       0.80      1.00      0.89    480225
#            0       0.00      0.00      0.00    119775
#
#     accuracy                           0.80    600000
#    macro avg       0.40      0.50      0.44    600000
# weighted avg       0.64      0.80      0.71    600000

# %%
from sklearn.neural_network import MLPClassifier
print('Columns for test data is Increasing Speed , ' )
#df=df.sample(frac=0.10)
X = df[['IS_1']].copy()
#X = df[['DnI_2','IS_2','IDS_2','DS_2']].copy()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
y = df['Category'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

clf = MLPClassifier(random_state=1, max_iter=600).fit(X_train, y_train)
clf.predict_proba(X_test[:1])

clf.predict(X_test)


clf.score(X_test, y_test)

print(clf.score(X_test,y_test))

metrics.plot_confusion_matrix(clf,X_test,y_test)
#print(y_test)
test_predictions=clf.predict(X_test)
print(test_predictions)
print(clf)

#print(y_test)
print(y_test.shape,test_predictions.shape)
meu.get_metrics(true_labels=y_test,predicted_labels=test_predictions)
#accuracy_score(y_test,test_predictions)
cm=sklearn.metrics.confusion_matrix(y_test,test_predictions)
#meu.display_confusion_matrix(y_test,test_predictions)
meu.display_classification_report(true_labels=y_test, predicted_labels=test_predictions,
                                  classes=df.Category.unique())
del X
del y
# Out:
# Columns for test data is Increasing Speed ,
# 0.35650166666666666
# <img src="data:image/png;base64,..." width="432">
# [0 2 2 ... 2 0 5]
# MLPClassifier(max_iter=600, random_state=1)
# (600000,) (600000,)
# Accuracy: 0.3565
# Precision: 0.3018
# Recall: 0.3565
# F1 Score: 0.315
#               precision    recall  f1-score   support
#
#            4       0.61      0.65      0.63    120490
#            3       0.08      0.00      0.00     80503
#            0       0.27      0.25      0.26    119474
#            2       0.30      0.58      0.40    119775
#            1       0.00      0.00      0.00     39861
#            5       0.27      0.30      0.29    119897
#
#     accuracy                           0.36    600000
#    macro avg       0.26      0.30      0.26    600000
# weighted avg       0.30      0.36      0.32    600000
